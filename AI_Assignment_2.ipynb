# %% [markdown]
# <a href="https://colab.research.google.com/github/Maxwell-Gitonga/AI-Coursework2025-2-/blob/Question-4/AI_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question 4
#
# Time:It is MAR because the missingness most likely depends on other factors such as the operator who was working at the time. Thus the data mining question needs to be refined.
#
# Location:It is MAR because the missingness likely depends on the operator i.e if it was a military flight the location is likely to be withheld. Thus the data mining question needs to be refined.
#
# Operator:It is MAR because the missingness likely depends on the type if it is military and more secretive.The data mining question needs to be refined.
#
# Flight #:It is MNAR because the missingness most likely depends on the date. Early fligts did not have flight numbers.The missing records should be imputed with a constant.
#
# Route:It is MNAR because likely depends on if the location was recorded.The missing records should be imputed with a constant.
#
# Type: It is MAR because it most likely depends on if it was military thus classified or if the records are older .The missing data mining question should be refined.
#
# Registration: It is MNAR because the missingness likely depends on the type of aircraft. Thus the missing records should be imputed with a constant.
#
# cn/In:It is MNAR because it  likely depends on the type of aircraft and if it was in the early dates.The missing data should be imputed with a constant.
#
# Aboard:It is MAR because the number of people aboard depends on the type of aircraft .The data mining question needs to be refined.
#
# Fatalities:It is MAR because it the missingness depends on the aboard column .The data mining question needs to be refined.
#
# Ground: It is MCAR because the missingness does not really depend on any other column.Drop the rows with missing values.
#
# Summary:It is MNAR because the missingness depends on the type of aircraft i.e if it is a military aircraft it is most  likely to be classified .The data missing data should be imputed with a constant.

# %%
import pandas as pd
import numpy as np

from google.colab import files
uploaded = files.upload()
df = pd.read_csv("Airplane_Crashes_and_Fatalities_Since_1908.csv")

df.info()
df.isna().sum()
# Out:
#      <input type="file" id="files-885750fd-6983-47c3-87b7-7ad6489c7661" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-885750fd-6983-47c3-87b7-7ad6489c7661">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
